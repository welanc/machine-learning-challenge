# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load csv pre-processed CSV data as DataFrame
data = pd.read_csv("../data/output.csv")

df = pd.DataFrame(data)
df.head()
# Out:
#    Unnamed: 0     kepid kepoi_name koi_disposition koi_pdisposition  \
# 0           0  10797460  K00752.01       CONFIRMED        CANDIDATE
# 1           1  10797460  K00752.02       CONFIRMED        CANDIDATE
# 2           2  10811496  K00753.01  FALSE POSITIVE   FALSE POSITIVE
# 3           3  10848459  K00754.01  FALSE POSITIVE   FALSE POSITIVE
# 4           4  10854555  K00755.01       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0      1.000              0              0              0              0
# 1      0.969              0              0              0              0
# 2      0.000              0              1              0              0
# 3      0.000              0              1              0              0
# 4      1.000              0              0              0              0
#
#    koi_period  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 0    9.488036       0.146       2.95750      615.8      2.26    793.0
# 1   54.418383       0.586       4.50700      874.8      2.83    443.0
# 2   19.899140       0.969       1.78220    10829.0     14.60    638.0
# 3    1.736952       1.276       2.40641     8079.2     33.46   1395.0
# 4    2.525592       0.701       1.65450      603.3      2.75   1406.0
#
#    koi_model_snr  koi_steff  koi_slogg  koi_srad
# 0           35.8     5455.0      4.467     0.927
# 1           25.8     5455.0      4.467     0.927
# 2           76.3     5853.0      4.544     0.868
# 3          505.6     5805.0      4.564     0.791
# 4           40.9     6031.0      4.438     1.046

# %%
df = df.drop(columns=["Unnamed: 0"])
df.head()
# Out:
#       kepid kepoi_name koi_disposition koi_pdisposition  koi_score  \
# 0  10797460  K00752.01       CONFIRMED        CANDIDATE      1.000
# 1  10797460  K00752.02       CONFIRMED        CANDIDATE      0.969
# 2  10811496  K00753.01  FALSE POSITIVE   FALSE POSITIVE      0.000
# 3  10848459  K00754.01  FALSE POSITIVE   FALSE POSITIVE      0.000
# 4  10854555  K00755.01       CONFIRMED        CANDIDATE      1.000
#
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0    9.488036
# 1              0              0              0              0   54.418383
# 2              0              1              0              0   19.899140
# 3              0              1              0              0    1.736952
# 4              0              0              0              0    2.525592
#
#    koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  koi_model_snr  \
# 0       0.146       2.95750      615.8      2.26    793.0           35.8
# 1       0.586       4.50700      874.8      2.83    443.0           25.8
# 2       0.969       1.78220    10829.0     14.60    638.0           76.3
# 3       1.276       2.40641     8079.2     33.46   1395.0          505.6
# 4       0.701       1.65450      603.3      2.75   1406.0           40.9
#
#    koi_steff  koi_slogg  koi_srad
# 0     5455.0      4.467     0.927
# 1     5455.0      4.467     0.927
# 2     5853.0      4.544     0.868
# 3     5805.0      4.564     0.791
# 4     6031.0      4.438     1.046

# %%
df["koi_disposition"].value_counts()
# Out:
# FALSE POSITIVE    3922
# CONFIRMED         2281
# CANDIDATE         1792
# Name: koi_disposition, dtype: int64

# %%
df_dummies = pd.get_dummies(df["koi_disposition"])
df_dummies.head()
# Out:
#    CANDIDATE  CONFIRMED  FALSE POSITIVE
# 0          0          1               0
# 1          0          1               0
# 2          0          0               1
# 3          0          0               1
# 4          0          1               0

# %%
df = df.merge(df_dummies, left_index=True, right_index=True, how="outer")

# %%
df
# Out:
#          kepid kepoi_name koi_disposition koi_pdisposition  koi_score  \
# 0     10797460  K00752.01       CONFIRMED        CANDIDATE      1.000
# 1     10797460  K00752.02       CONFIRMED        CANDIDATE      0.969
# 2     10811496  K00753.01  FALSE POSITIVE   FALSE POSITIVE      0.000
# 3     10848459  K00754.01  FALSE POSITIVE   FALSE POSITIVE      0.000
# 4     10854555  K00755.01       CONFIRMED        CANDIDATE      1.000
# ...        ...        ...             ...              ...        ...
# 7990  10031643  K07984.01  FALSE POSITIVE   FALSE POSITIVE      0.000
# 7991  10090151  K07985.01  FALSE POSITIVE   FALSE POSITIVE      0.000
# 7992  10128825  K07986.01       CANDIDATE        CANDIDATE      0.497
# 7993  10147276  K07987.01  FALSE POSITIVE   FALSE POSITIVE      0.021
# 7994  10156110  K07989.01  FALSE POSITIVE   FALSE POSITIVE      0.000
#
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0    9.488036
# 1                 0              0              0              0   54.418383
# 2                 0              1              0              0   19.899140
# 3                 0              1              0              0    1.736952
# 4                 0              0              0              0    2.525592
# ...             ...            ...            ...            ...         ...
# 7990              0              0              0              1    8.589871
# 7991              0              1              1              0    0.527699
# 7992              0              0              0              0    1.739849
# 7993              0              0              1              0    0.681402
# 7994              0              0              1              1    4.856035
#
#       ...  koi_depth  koi_prad  koi_teq  koi_model_snr  koi_steff  koi_slogg  \
# 0     ...      615.8      2.26    793.0           35.8     5455.0      4.467
# 1     ...      874.8      2.83    443.0           25.8     5455.0      4.467
# 2     ...    10829.0     14.60    638.0           76.3     5853.0      4.544
# 3     ...     8079.2     33.46   1395.0          505.6     5805.0      4.564
# 4     ...      603.3      2.75   1406.0           40.9     6031.0      4.438
# ...   ...        ...       ...      ...            ...        ...        ...
# 7990  ...       87.7      1.11    929.0            8.4     5638.0      4.296
# 7991  ...     1579.2     29.35   2088.0          453.3     5638.0      4.529
# 7992  ...       48.5      0.72   1608.0           10.6     6119.0      4.444
# 7993  ...      103.6      1.07   2218.0           12.3     6173.0      4.447
# 7994  ...       76.7      1.05   1266.0            8.2     6469.0      4.385
#
#       koi_srad  CANDIDATE  CONFIRMED  FALSE POSITIVE
# 0        0.927          0          1               0
# 1        0.927          0          1               0
# 2        0.868          0          0               1
# 3        0.791          0          0               1
# 4        1.046          0          1               0
# ...        ...        ...        ...             ...
# 7990     1.088          0          0               1
# 7991     0.903          0          0               1
# 7992     1.031          1          0               0
# 7993     1.041          0          0               1
# 7994     1.193          0          0               1
#
# [7995 rows x 22 columns]

# %%
# Assign X (data) and y (target)

X = df[["CANDIDATE",
        "CONFIRMED", 
        "FALSE POSITIVE",
        "koi_period",
        "koi_impact",
        "koi_duration",
        "koi_depth",
        "koi_prad"
       ]]
y = df["koi_score"].values.reshape(-1,1)

print(X.shape, y.shape)
# Out:
# (7995, 8) (7995, 1)

# %%
# Split the data into training and testing

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a StandardScater model and fit it to the training data

X_scaler = MinMaxScaler().fit(X_train)
y_scaler = MinMaxScaler().fit(y_train)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
